# %%
# coding=gbk
import os
import wave
import numpy as np
import pylab as plt

CutTimeDef = 2  # 以1s截断文件
# CutTimeDef = 2  while StepTotalNum < nframes*2:  时截取1s的音频时间

path = r"D:\chainsaw sounds\Chainsaw5s"
files = os.listdir(path)
files = [path + "\\" + f for f in files if f.endswith('.wav')]
print(files)

def SetFileName(WavFileName):
    for i in range(len(files)):
        FileName = files[i]
        print("SetFileName File Name is ", FileName)
        FileName = WavFileName


def CutFile():
    for i in range(len(files)):
        FileName = files[i]
        print("CutFile File Name is ", FileName)
        f = wave.open(r"" + FileName, "rb")
        params = f.getparams()
        print(params)
        nchannels, sampwidth, framerate, nframes = params[:4]
        CutFrameNum = framerate * CutTimeDef
        # 读取格式信息
        # 一次性返回所有的WAV文件的格式信息，它返回的是一个组元(tuple)：声道数, 量化位数（byte    单位）, 采
        # 样频率, 采样点数, 压缩类型, 压缩类型的描述。wave模块只支持非压缩的数据，因此可以忽略最后两个信息

        # print("CutFrameNum=%d" % (CutFrameNum))
        # print("nchannels=%d" % (nchannels))
        # print("sampwidth=%d" % (sampwidth))
        # print("framerate=%d" % (framerate))
        # print("nframes=%d" % (nframes))
        str_data = f.readframes(nframes)
        f.close()  # 将波形数据转换成数组
        # 需要根据声道数和量化单位，将读取的二进制数据转换为一个可以计算的数组
        wave_data = np.fromstring(str_data, dtype=np.short)
        if nchannels > 1:
            wave_data.reshape(-1, nframes)
            wave_data = wave_data.T
            temp_data = wave_data.T
        else:
            wave_data = wave_data.T
            print(wave_data.shape)
            temp_data = wave_data.T
        StepNum = CutFrameNum
        StepTotalNum = 0
        haha = 0
        while StepTotalNum < nframes*2:
            print("Stemp=%d" % (haha))
            FileName = r"D:\chainsaw sounds\Chainsaw5s\test" + files[i][-9:-4] + '_' + str(haha + 1) + ".wav"
            print(FileName)
            temp_dataTemp = temp_data[StepNum * (haha):StepNum * (haha + 1)]
            haha = haha + 1
            StepTotalNum = haha * StepNum
            temp_dataTemp.shape = 1, -1
            temp_dataTemp = temp_dataTemp.astype(np.short)  # 打开WAV文档
            f = wave.open(FileName, "wb")  #
            # 配置声道数、量化位数和取样频率
            f.setnchannels(nchannels)
            f.setsampwidth(sampwidth)
            f.setframerate(framerate)
            # 将wav_data转换为二进制数据写入文件
            f.writeframes(temp_dataTemp.tostring())
            f.close()


if __name__ == '__main__':
    CutFile()
# Out:
# ['D:\\chainsaw sounds\\Chainsaw5s\\chainaw-10_1.wav', 'D:\\chainsaw sounds\\Chainsaw5s\\chainaw-10_10.wav', 'D:\\chainsaw sounds\\Chainsaw5s\\chainaw-10_13.wav', 'D:\\chainsaw sounds\\Chainsaw5s\\chainaw-10_14.wav', 'D:\\chainsaw sounds\\Chainsaw5s\\chainaw-10_15.wav', 'D:\\chainsaw sounds\\Chainsaw5s\\chainaw-10_16.wav', 'D:\\chainsaw sounds\\Chainsaw5s\\chainaw-10_17.wav', 'D:\\chainsaw sounds\\Chainsaw5s\\chainaw-10_18.wav', 'D:\\chainsaw sounds\\Chainsaw5s\\chainaw-10_19.wav', 'D:\\chainsaw sounds\\Chainsaw5s\\chainaw-10_2.wav', 'D:\\chainsaw sounds\\Chainsaw5s\\chainaw-10_20.wav', 'D:\\chainsaw sounds\\Chainsaw5s\\chainaw-10_21.wav', 'D:\\chainsaw sounds\\Chainsaw5s\\chainaw-10_22.wav', 'D:\\chainsaw sounds\\Chainsaw5s\\chainaw-10_23.wav', 'D:\\chainsaw sounds\\Chainsaw5s\\chainaw-10_24.wav', 'D:\\chainsaw sounds\\Chainsaw5s\\chainaw-10_25.wav', 'D:\\chainsaw sounds\\Chainsaw5s\\chainaw-10_26.wav', 'D:\\chainsaw sounds\\Chainsaw5s\\chainaw-10_27.wav', 'D:\\chainsaw sounds\\Chainsaw5s\\chainaw-10_28.wav', 'D:\\chainsaw sounds\\Chainsaw5s\\chainaw-10_29.wav', 'D:\\chainsaw sounds\\Chainsaw5s\\chainaw-10_3.wav', 'D:\\chainsaw sounds\\Chainsaw5s\\chainaw-10_30.wav', 'D:\\chainsaw sounds\\Chainsaw5s\\chainaw-10_31.wav', 'D:\\chainsaw sounds\\Chainsaw5s\\chainaw-10_33.wav', 'D:\\chainsaw sounds\\Chainsaw5s\\chainaw-10_37.wav', 'D:\\chainsaw sounds\\Chainsaw5s\\chainaw-10_38.wav', 'D:\\chainsaw sounds\\Chainsaw5s\\chainaw-10_39.wav', 'D:\\chainsaw sounds\\Chainsaw5s\\chainaw-10_40.wav', 'D:\\chainsaw sounds\\Chainsaw5s\\chainaw-10_41.wav', 'D:\\chainsaw sounds\\Chainsaw5s\\chainaw-10_42.wav', 'D:\\chainsaw sounds\\Chainsaw5s\\chainaw-10_43.wav', 'D:\\chainsaw sounds\\Chainsaw5s\\chainaw-10_44.wav', 'D:\\chainsaw sounds\\Chainsaw5s\\chainaw-10_6.wav', 'D:\\chainsaw sounds\\Chainsaw5s\\chainaw-13_2.wav', 'D:\\chainsaw sounds\\Chainsaw5s\\chainaw-13_3.wav', 'D:\\chainsaw sounds\\Chainsaw5s\\chainaw-14_1.wav', 'D:\\chainsaw sounds\\Chainsaw5s\\chainaw-14_10.wav', 'D:\\chainsaw sounds\\Chainsaw5s\\chainaw-14_11.wav', 'D:\\chainsaw sounds\\Chainsaw5s\\chainaw-14_12.wav', 'D:\\chainsaw sounds\\Chainsaw5s\\chainaw-14_13.wav', 'D:\\chainsaw sounds\\Chainsaw5s\\chainaw-14_14.wav', 'D:\\chainsaw sounds\\Chainsaw5s\\chainaw-14_15.wav', 'D:\\chainsaw sounds\\Chainsaw5s\\chainaw-14_17.wav', 'D:\\chainsaw sounds\\Chainsaw5s\\chainaw-14_19.wav', 'D:\\chainsaw sounds\\Chainsaw5s\\chainaw-14_3.wav', 'D:\\chainsaw sounds\\Chainsaw5s\\chainaw-14_6.wav', 'D:\\chainsaw sounds\\Chainsaw5s\\chainaw-14_7.wav', 'D:\\chainsaw sounds\\Chainsaw5s\\chainaw-15_11.wav', 'D:\\chainsaw sounds\\Chainsaw5s\\chainaw-15_5.wav', 'D:\\chainsaw sounds\\Chainsaw5s\\chainaw-15_7.wav', 'D:\\chainsaw sounds\\Chainsaw5s\\chainaw-15_9.wav', 'D:\\chainsaw sounds\\Chainsaw5s\\chainaw-16_1.wav', 'D:\\chainsaw sounds\\Chainsaw5s\\chainaw-16_10.wav', 'D:\\chainsaw sounds\\Chainsaw5s\\chainaw-16_11.wav', 'D:\\chainsaw sounds\\Chainsaw5s\\chainaw-16_12.wav', 'D:\\chainsaw sounds\\Chainsaw5s\\chainaw-16_13.wav', 'D:\\chainsaw sounds\\Chainsaw5s\\chainaw-16_14.wav', 'D:\\chainsaw sounds\\Chainsaw5s\\chainaw-16_15.wav', 'D:\\chainsaw sounds\\Chainsaw5s\\chainaw-16_3.wav', 'D:\\chainsaw sounds\\Chainsaw5s\\chainaw-16_4.wav', 'D:\\chainsaw sounds\\Chainsaw5s\\chainaw-16_5.wav', 'D:\\chainsaw sounds\\Chainsaw5s\\chainaw-16_6.wav', 'D:\\chainsaw sounds\\Chainsaw5s\\chainaw-16_7.wav', 'D:\\chainsaw sounds\\Chainsaw5s\\chainaw-16_8.wav', 'D:\\chainsaw sounds\\Chainsaw5s\\chainaw-16_9.wav', 'D:\\chainsaw sounds\\Chainsaw5s\\chainaw-18_1.wav', 'D:\\chainsaw sounds\\Chainsaw5s\\chainaw-18_10.wav', 'D:\\chainsaw sounds\\Chainsaw5s\\chainaw-18_2.wav', 'D:\\chainsaw sounds\\Chainsaw5s\\chainaw-18_3.wav', 'D:\\chainsaw sounds\\Chainsaw5s\\chainaw-18_4.wav', 'D:\\chainsaw sounds\\Chainsaw5s\\chainaw-18_5.wav', 'D:\\chainsaw sounds\\Chainsaw5s\\chainaw-18_6.wav', 'D:\\chainsaw sounds\\Chainsaw5s\\chainaw-18_7.wav', 'D:\\chainsaw sounds\\Chainsaw5s\\chainaw-18_8.wav', 'D:\\chainsaw sounds\\Chainsaw5s ...
# CutFile File Name is  D:\chainsaw sounds\Chainsaw5s\chainaw-10_1.wav
# _wave_params(nchannels=2, sampwidth=2, framerate=44100, nframes=220500, comptype='NONE', compname='not compressed')
# Stemp=0
# D:\chainsaw sounds\Chainsaw5s\test
2.wav
# Stemp=2
# D:\chainsaw sounds\Chainsaw5s\test-4_58_3.wav
# Stemp=3
# D:\chainsaw sounds\Chainsaw5s\test-4_58_4.wav
# Stemp=4
# D:\chainsaw sounds\Chainsaw5s\test-4_58_5.wav
# CutFile File Name is  D:\chainsaw sounds\Chainsaw5s\chainsaw-4_59.wav
# _wave_params(nchannels=2, sampwidth=2, framerate=44100, nframes=220500, comptype='NONE', compname='not compressed')
# Stemp=0
# D:\chainsaw sounds\Chainsaw5s\test-4_59_1.wav
# Stemp=1
# D:\chainsaw sounds\Chainsaw5s\test-4_59_2.wav
# Stemp=2
# D:\chainsaw sounds\Chainsaw5s\test-4_59_3.wav
# Stemp=3
# D:\chainsaw sounds\Chainsaw5s\test-4_59_4.wav
# Stemp=4
# D:\chainsaw sounds\Chainsaw5s\test-4_59_5.wav
# CutFile File Name is  D:\chainsaw sounds\Chainsaw5s\chainsaw-4_6.wav
# _wave_params(nchannels=2, sampwidth=2, framerate=44100, nframes=220500, comptype='NONE', compname='not compressed')
# Stemp=0
# D:\chainsaw sounds\Chainsaw5s\testw-4_6_1.wav
# Stemp=1
# D:\chainsaw sounds\Chainsaw5s\testw-4_6_2.wav
# Stemp=2
# D:\chainsaw sounds\Chainsaw5s\testw-4_6_3.wav
# Stemp=3
# D:\chainsaw sounds\Chainsaw5s\testw-4_6_4.wav
# Stemp=4
# D:\chainsaw sounds\Chainsaw5s\testw-4_6_5.wav
# CutFile File Name is  D:\chainsaw sounds\Chainsaw5s\chainsaw-4_60.wav
# _wave_params(nchannels=2, sampwidth=2, framerate=44100, nframes=220500, comptype='NONE', compname='not compressed')
# Stemp=0
# D:\chainsaw sounds\Chainsaw5s\test-4_60_1.wav
# Stemp=1
# D:\chainsaw sounds\Chainsaw5s\test-4_60_2.wav
# Stemp=2
# D:\chainsaw sounds\Chainsaw5s\test-4_60_3.wav
# Stemp=3
# D:\chainsaw sounds\Chainsaw5s\test-4_60_4.wav
# Stemp=4
# D:\chainsaw sounds\Chainsaw5s\test-4_60_5.wav
# CutFile File Name is  D:\chainsaw sounds\Chainsaw5s\chainsaw-4_61.wav
# _wave_params(nchannels=2, sampwidth=2, framerate=44100, nframes=220500, comptype='NONE', compname='not compressed')
# Stemp=0
# D:\chainsaw sounds\Chainsaw5s\test-4_61_1.wav
# Stemp=1
# D:\chainsaw sounds\Chainsaw5s\test-4_61_2.wav
# Stemp=2
# D:\chainsaw sounds\Chainsaw5s\test-4_61_3.wav
# Stemp=3
# D:\chainsaw sounds\Chainsaw5s\test-4_61_4.wav
# Stemp=4
# D:\chainsaw sounds\Chainsaw5s\test-4_61_5.wav
# CutFile File Name is  D:\chainsaw sounds\Chainsaw5s\chainsaw-4_62.wav
# _wave_params(nchannels=2, sampwidth=2, framerate=44100, nframes=220500, comptype='NONE', compname='not compressed')
# Stemp=0
# D:\chainsaw sounds\Chainsaw5s\test-4_62_1.wav
# Stemp=1
# D:\chainsaw sounds\Chainsaw5s\test-4_62_2.wav
# Stemp=2
# D:\chainsaw sounds\Chainsaw5s\test-4_62_3.wav
# Stemp=3
# D:\chainsaw sounds\Chainsaw5s\test-4_62_4.wav
# Stemp=4
# D:\chainsaw sounds\Chainsaw5s\test-4_62_5.wav
# CutFile File Name is  D:\chainsaw sounds\Chainsaw5s\chainsaw-4_63.wav
# _wave_params(nchannels=2, sampwidth=2, framerate=44100, nframes=220500, comptype='NONE', compname='not compressed')
# Stemp=0
# D:\chainsaw sounds\Chainsaw5s\test-4_63_1.wav
# Stemp=1
# D:\chainsaw sounds\Chainsaw5s\test-4_63_2.wav
# Stemp=2
# D:\chainsaw sounds\Chainsaw5s\test-4_63_3.wav
# Stemp=3
# D:\chainsaw sounds\Chainsaw5s\test-4_63_4.wav
# Stemp=4
# D:\chainsaw sounds\Chainsaw5s\test-4_63_5.wav
# CutFile File Name is  D:\chainsaw sounds\Chainsaw5s\chainsaw-4_7.wav
# _wave_params(nchannels=2, sampwidth=2, framerate=44100, nframes=220500, comptype='NONE', compname='not compressed')
# Stemp=0
# D:\chainsaw sounds\Chainsaw5s\testw-4_7_1.wav
# Stemp=1
# D:\chainsaw sounds\Chainsaw5s\testw-4_7_2.wav
# Stemp=2
# D:\chainsaw sounds\Chainsaw5s\testw-4_7_3.wav
# Stemp=3
# D:\chainsaw sounds\Chainsaw5s\testw-4_7_4.wav
# Stemp=4
# D:\chainsaw sounds\Chainsaw5s\testw-4_7_5.wav
# CutFile File Name is  D:\chainsaw sounds\Chainsaw5s\chainsaw-4_8.wav
# _wave_params(nchannels=2, sampwidth=2, framerate=44100, nframes=220500, comptype='NONE', compname='not compressed')
# Stemp=0
# D:\chainsaw sounds\Chainsaw5s\testw-4_8_1.wav
# Stemp=1
# D:\chainsaw sounds\Chainsaw5s\testw-4_8_2.wav
# Stemp=2
# D:\chainsaw sounds\Chainsaw5s\testw-4_8_3.wav
# Stemp=3
# D:\chainsaw sounds\Chainsaw5s\testw-4_8_4.wav
# Stemp=4
# D:\chainsaw sounds\Chainsaw5s\testw-4_8_5.wav
# CutFile File Name is  D:\chainsaw sounds\Chainsaw5s\chainsaw-4_9.wav
# _wave_params(nchannels=2, sampwidth=2, framerate=44100, nframes=220500, comptype='NONE', compname='not compressed')
# Stemp=0
# D:\chainsaw sounds\Chainsaw5s\testw-4_9_1.wav
# Stemp=1
# D:\chainsaw sounds\Chainsaw5s\testw-4_9_2.wav
# Stemp=2
# D:\chainsaw sounds\Chainsaw5s\testw-4_9_3.wav
# Stemp=3
# D:\chainsaw sounds\Chainsaw5s\testw-4_9_4.wav
# Stemp=4
# D:\chainsaw sounds\Chainsaw5s\testw-4_9_5.wav
# CutFile File Name is  D:\chainsaw sounds\Chainsaw5s\chainsaw-5_10.wav
# _wave_params(nchannels=2, sampwidth=2, framerate=44100, nframes=220500, comptype='NONE', compname='not compressed')
# Stemp=0
# D:\chainsaw sounds\Chainsaw5s\test-5_10_1.wav
# Stemp=1
# D:\chainsaw sounds\Chainsaw5s\test-5_10_2.wav
# Stemp=2
# D:\chainsaw sounds\Chainsaw5s\test-5_10_3.wav
# Stemp=3
# D:\chainsaw sounds\Chainsaw5s\test-5_10_4.wav
# Stemp=4
# D:\chainsaw sounds\Chainsaw5s\test-5_10_5.wav
# CutFile File Name is  D:\chainsaw sounds\Chainsaw5s\chainsaw-5_11.wav
# _wave_params(nchannels=2, sampwidth=2, framerate=44100, nframes=220500, comptype='NONE', compname='not compressed')
# Stemp=0
# D:\chainsaw sounds\Chainsaw5s\test-5_11_1.wav
# Stemp=1
# D:\chainsaw sounds\Chainsaw5s\test-5_11_2.wav
# Stemp=2
# D:\chainsaw sounds\Chainsaw5s\test-5_11_3.wav
# Stemp=3
# D:\chainsaw sounds\Chainsaw5s\test-5_11_4.wav
# Stemp=4
# D:\chainsaw sounds\Chainsaw5s\test-5_11_5.wav
# CutFile File Name is  D:\chainsaw sounds\Chainsaw5s\chainsaw-5_12.wav
# _wave_params(nchannels=2, sampwidth=2, framerate=44100, nframes=220500, comptype='NONE', compname='not compressed')
# Stemp=0
# D:\chainsaw sounds\Chainsaw5s\test-5_12_1.wav
# Stemp=1
# D:\chainsaw sounds\Chainsaw5s\test-5_12_2.wav
# Stemp=2
# D:\chainsaw sounds\Chainsaw5s\test-5_12_3.wav
# Stemp=3
# D:\chainsaw sounds\Chainsaw5s\test-5_12_4.wav
# Stemp=4
# D:\chainsaw sounds\Chainsaw5s\test-5_12_5.wav
# CutFile File Name is  D:\chainsaw sounds\Chainsaw5s\chainsaw-5_13.wav
# _wave_params(nchannels=2, sampwidth=2, framerate=44100, nframes=220500, comptype='NONE', compname='not compressed')
# Stemp=0
# D:\chainsaw sounds\Chainsaw5s\test-5_13_1.wav
# Stemp=1
# D:\chainsaw sounds\Chainsaw5s\test-5_13_2.wav
# Stemp=2
# D:\chainsaw sounds\Chainsaw5s\test-5_13_3.wav
# Stemp=3
# D:\chainsaw sounds\Chainsaw5s\test-5_13_4.wav
# Stemp=4
# D:\chainsaw sounds\Chainsaw5s\test-5_13_5.wav
# CutFile File Name is  D:\chainsaw sounds\Chainsaw5s\chainsaw-5_14.wav
# _wave_params(nchannels=2, sampwidth=2, framerate=44100, nframes=220500, comptype='NONE', compname='not compressed')
# Stemp=0
# D:\chainsaw sounds\Chainsaw5s\test-5_14_1.wav
# Stemp=1
# D:\chainsaw sounds\Chainsaw5s\test-5_14_2.wav
# Stemp=2
# D:\chainsaw sounds\Chainsaw5s\test-5_14_3.wav
# Stemp=3
# D:\chainsaw sounds\Chainsaw5s\test-5_14_4.wav
# Stemp=4
# D:\chainsaw sounds\Chainsaw5s\test-5_14_5.wav
# CutFile File Name is  D:\chainsaw sounds\Chainsaw5s\chainsaw-5_2.wav
# _wave_params(nchannels=2, sampwidth=2, framerate=44100, nframes=220500, comptype='NONE', compname='not compressed')
# Stemp=0
# D:\chainsaw sounds\Chainsaw5s\testw-5_2_1.wav
# Stemp=1
# D:\chainsaw sounds\Chainsaw5s\testw-5_2_2.wav
# Stemp=2
# D:\chainsaw sounds\Chainsaw5s\testw-5_2_3.wav
# Stemp=3
# D:\chainsaw sounds\Chainsaw5s\testw-5_2_4.wav
# Stemp=4
# D:\chainsaw sounds\Chainsaw5s\testw-5_2_5.wav
# CutFile File Name is  D:\chainsaw sounds\Chainsaw5s\chainsaw-5_3.wav
# _wave_params(nchannels=2, sampwidth=2, framerate=44100, nframes=220500, comptype='NONE', compname='not compressed')
# Stemp=0
# D:\chainsaw sounds\Chainsaw5s\testw-5_3_1.wav
# Stemp=1
# D:\chainsaw sounds\Chainsaw5s\testw-5_3_2.wav
# Stemp=2
# D:\chainsaw sounds\Chainsaw5s\testw-5_3_3.wav
# Stemp=3
# D:\chainsaw sounds\Chainsaw5s\testw-5_3_4.wav
# Stemp=4
# D:\chainsaw sounds\Chainsaw5s\testw-5_3_5.wav
# CutFile File Name is  D:\chainsaw sounds\Chainsaw5s\chainsaw-5_4.wav
# _wave_params(nchannels=2, sampwidth=2, framerate=44100, nframes=220500, comptype='NONE', compname='not compressed')
# Stemp=0
# D:\chainsaw sounds\Chainsaw5s\testw-5_4_1.wav
# Stemp=1
# D:\chainsaw sounds\Chainsaw5s\testw-5_4_2.wav
# Stemp=2
# D:\chainsaw sounds\Chainsaw5s\testw-5_4_3.wav
# Stemp=3
# D:\chainsaw sounds\Chainsaw5s\testw-5_4_4.wav
# Stemp=4
# D:\chainsaw sounds\Chainsaw5s\testw-5_4_5.wav
# CutFile File Name is  D:\chainsaw sounds\Chainsaw5s\chainsaw-5_5.wav
# _wave_params(nchannels=2, sampwidth=2, framerate=44100, nframes=220500, comptype='NONE', compname='not compressed')
# Stemp=0
# D:\chainsaw sounds\Chainsaw5s\testw-5_5_1.wav
# Stemp=1
# D:\chainsaw sounds\Chainsaw5s\testw-5_5_2.wav
# Stemp=2
# D:\chainsaw sounds\Chainsaw5s\testw-5_5_3.wav
# Stemp=3
# D:\chainsaw sounds\Chainsaw5s\testw-5_5_4.wav
# Stemp=4
# D:\chainsaw sounds\Chainsaw5s\testw-5_5_5.wav
# CutFile File Name is  D:\chainsaw sounds\Chainsaw5s\chainsaw-5_6.wav
# _wave_params(nchannels=2, sampwidth=2, framerate=44100, nframes=220500, comptype='NONE', compname='not compressed')
# Stemp=0
# D:\chainsaw sounds\Chainsaw5s\testw-5_6_1.wav
# Stemp=1
# D:\chainsaw sounds\Chainsaw5s\testw-5_6_2.wav
# Stemp=2
# D:\chainsaw sounds\Chainsaw5s\testw-5_6_3.wav
# Stemp=3
# D:\chainsaw sounds\Chainsaw5s\testw-5_6_4.wav
# Stemp=4
# D:\chainsaw sounds\Chainsaw5s\testw-5_6_5.wav
# CutFile File Name is  D:\chainsaw sounds\Chainsaw5s\chainsaw-5_7.wav
# _wave_params(nchannels=2, sampwidth=2, framerate=44100, nframes=220500, comptype='NONE', compname='not compressed')
# Stemp=0
# D:\chainsaw sounds\Chainsaw5s\testw-5_7_1.wav
# Stemp=1
# D:\chainsaw sounds\Chainsaw5s\testw-5_7_2.wav
# Stemp=2
# D:\chainsaw sounds\Chainsaw5s\testw-5_7_3.wav
# Stemp=3
# D:\chainsaw sounds\Chainsaw5s\testw-5_7_4.wav
# Stemp=4
# D:\chainsaw sounds\Chainsaw5s\testw-5_7_5.wav
# CutFile File Name is  D:\chainsaw sounds\Chainsaw5s\chainsaw-5_8.wav
# _wave_params(nchannels=2, sampwidth=2, framerate=44100, nframes=220500, comptype='NONE', compname='not compressed')
# Stemp=0
# D:\chainsaw sounds\Chainsaw5s\testw-5_8_1.wav
# Stemp=1
# D:\chainsaw sounds\Chainsaw5s\testw-5_8_2.wav
# Stemp=2
# D:\chainsaw sounds\Chainsaw5s\testw-5_8_3.wav
# Stemp=3
# D:\chainsaw sounds\Chainsaw5s\testw-5_8_4.wav
# Stemp=4
# D:\chainsaw sounds\Chainsaw5s\testw-5_8_5.wav
# CutFile File Name is  D:\chainsaw sounds\Chainsaw5s\chainsaw-5_9.wav
# _wave_params(nchannels=2, sampwidth=2, framerate=44100, nframes=220500, comptype='NONE', compname='not compressed')
# Stemp=0
# D:\chainsaw sounds\Chainsaw5s\testw-5_9_1.wav
# Stemp=1
# D:\chainsaw sounds\Chainsaw5s\testw-5_9_2.wav
# Stemp=2
# D:\chainsaw sounds\Chainsaw5s\testw-5_9_3.wav
# Stemp=3
# D:\chainsaw sounds\Chainsaw5s\testw-5_9_4.wav
# Stemp=4
# D:\chainsaw sounds\Chainsaw5s\testw-5_9_5.wav

# %%
CutFile()
# Out:
# CutFile File Name is  C:\Users\Asitonie\Desktop\1\foreast-14.wav
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-5-ed3427e4cb2e> in <module>
# ----> 1 CutFile()
#
# <ipython-input-3-0a1d3cf5e94a> in CutFile()
#      24         FileName = files[i]
#      25         print("CutFile File Name is ", FileName)
# ---> 26         f = wave.open(r"" + FileName, "rb")
#      27         params = f.getparams()
#      28         print(params)
#
# D:\ANACONDA3\lib\wave.py in open(f, mode)
#     508             mode = 'rb'
#     509     if mode in ('r', 'rb'):
# --> 510         return Wave_read(f)
#     511     elif mode in ('w', 'wb'):
#     512         return Wave_write(f)
#
# D:\ANACONDA3\lib\wave.py in __init__(self, f)
#     158         self._i_opened_the_file = None
#     159         if isinstance(f, str):
# --> 160             f = builtins.open(f, 'rb')
#     161             self._i_opened_the_file = f
#     162         # else, assume it is an open file object already
#
# FileNotFoundError: [Errno 2] No such file or directory: 'C:\\Users\\Asitonie\\Desktop\\1\\foreast-14.wav'
